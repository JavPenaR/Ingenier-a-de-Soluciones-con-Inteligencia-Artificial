# %% [markdown]
# ## Primera Llamada al Modelo
#
# En este ejercicio, aprenderemos a realizar nuestra primera llamada a un modelo de lenguaje usando la API de Gemini
#
# # 1.  Gemini API - Conexión Directa con OpenAI Client
#
# ## Objetivos de Aprendizaje
# - Configurar una conexión directa con Gemini usando el cliente OpenAI
# - Comprender los parámetros básicos de configuración de API
# - Implementar llamadas básicas a modelos de lenguaje
# - Aplicar mejores prácticas de seguridad con API keys
#
# ## Introducción
# Gemini  proporciona acceso a varios modelos de lenguaje mediante una API compatible con OpenAI. En este notebook aprenderemos a:
# 1. Configurar el entorno y las credenciales
# 2. Establecer una conexión con la API
# 3. Realizar llamadas básicas al modelo
# 4. Explorar diferentes parámetros de configuración
#
# ## Configuración de Variables de Entorno
#
# Antes de ejecutar el código, asegúrate de tener configuradas las siguientes variables de entorno:
#
# ```bash
# export GEMINI_BASE_URL="https://generativelanguage.googleapis.com/v1beta/openai/"
# export GEMINI_API_KEY="tu_token_aqui"
# ```
#
# **Mejores Prácticas de Seguridad:**
# - Nunca hardcodees API keys en el código
# - Usa variables de entorno o archivos .env
# - No compartas credenciales en repositorios públicos
# - Rota las API keys regularmente
#
# ## Instalación de Dependencias
# ```bash
# pip install openai python-dotenv
# ```
#
# - `openai`: cliente que permite conectar con cualquier proveedor compatible con el formato OpenAI (Gemini, Groq, OpenRouter, etc.)
# - `python-dotenv`: permite cargar las variables de entorno (API keys, URLs) desde el archivo `.env` con `load_dotenv()`

# %%
# Importar las bibliotecas necesarias
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
# Verificar que tenemos las bibliotecas correctas
print("OpenAI library version:", __import__('openai').__version__)
print("Python version:", __import__('sys').version)

# Configuración del cliente OpenAI para GitHub Models

    # Configurar el cliente con variables de entorno
client = OpenAI(
    base_url=os.environ.get("GEMINI_BASE_URL"),
    api_key=os.environ.get("GEMINI_API_KEY")
)
# Out:
# OpenAI library version: 2.32.0
# Python version: 3.14.6 (tags/v3.14.6:c63aec6, Jun 10 2026, 10:26:10) [MSC v.1944 64 bit (AMD64)]

# %%
# Primera llamada básica al modelo
def llamada_basica():
    try:
        response = client.chat.completions.create(
            model="gemini-3.7-flash",
            messages=[
                {"role": "user", "content": "Hola, ¿cómo estás? Responde en una oración."}
            ],
            temperature=0.1,
            max_tokens=1000
        )
        
        print("=== Respuesta del Modelo ===")
        print(response.choices[0].message.content) # respuesta del modelo
        print("\n=== Información Técnica ===")
        print(f"Modelo usado: {response.model}")
        print(f"Tokens usados: {response.usage.total_tokens}") 
        print(f"Tokens de entrada: {response.usage.prompt_tokens}")
        print(f"Tokens de salida: {response.usage.completion_tokens}")
        
    except Exception as e:
        print(f"Error en la llamada: {e}")
        print("Verifica tu configuración y conexión a internet")

# Ejecutar la función
llamada_basica()
# Out:
# Error en la llamada: Error code: 503 - [{'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}]
# Verifica tu configuración y conexión a internet
# El kernel se bloqueó al ejecutar código en la celda actual o en una celda anterior.
#
# Revise el código de las celdas para identificar una posible causa del error.
#
# Haga clic <a href='https://aka.ms/vscodeJupyterKernelCrash'>aquí</a> para obtener más información.
#
# Vea Jupyter <a href='command:jupyter.viewOutput'>log</a> para obtener más detalles.

# %% [markdown]
# ## Usando Roles del Sistema
#
# El rol "system" permite establecer el comportamiento y contexto del asistente antes de la conversación.

# %%
# Ejemplo con mensaje de sistema
def usar_mensaje_sistema():
    try:
        response = client.chat.completions.create(
            model="gemini-3.6-flash",
            messages=[
                {
                    "role": "system", 
                    "content": "Eres un experto en tecnología que explica conceptos complejos de manera simple y amigable. Siempre incluyes ejemplos prácticos."
                },
                {
                    "role": "user", 
                    "content": "¿Qué es La Inteligencia Artificial?"
                }
            ],
            temperature=0.1,
            max_tokens=1000
        )
        
        print("=== Respuesta con Mensaje de Sistema ===")
        print(response.choices[0].message.content)
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar función
usar_mensaje_sistema()
# Out:
# === Respuesta con Mensaje de Sistema ===
# ¡Hola! Qué excelente pregunta. Es un tema fascinante y muy presente en nuestro día a día.
#
# Para explicarlo de forma muy sencilla: **la Inteligencia Artificial (IA) es la capacidad que le damos a las máquinas y computadoras para "pensar", aprender y resolver problemas casi como lo haría

# %% [markdown]
# ## Explorando Parámetros de Configuración
#
# Los parámetros más importantes al hacer llamadas a LLMs son:
#
# - **temperature**: Controla la creatividad (0.0 = determinístico, 1.0 = muy creativo)
# - **max_tokens**: Límite de tokens en la respuesta
# - **model**: El modelo específico a usar (gemini-3.6-flash, gemini-3.7-flash, etc.)
# - **messages**: Array de mensajes con roles (system, user, assistant)

# %%
# Comparando diferentes valores de temperature
def comparar_temperature():
    prompt = "Escribe una historia muy corta sobre un robot que aprende a cocinar."
    
    temperatures = [0.1, 0.5, 0.9]
    
    for temp in temperatures:
        print(f"\n{'='*50}")
        print(f"TEMPERATURE: {temp}")
        print('='*50)
        
        try:
            response = client.chat.completions.create(
                model="gemini-3.6-flash",
                messages=[{"role": "user", "content": prompt}],
                temperature=temp,
                max_tokens=2000
            )
            
            print(response.choices[0].message.content)
            print(f"\nTokens usados: {response.usage.total_tokens}")
            
        except Exception as e:
            print(f"Error: {e}")


# Ejecutar comparación
comparar_temperature()
# Out:
# ==================================================
# TEMPERATURE: 0.1
# ==================================================
# AX-4 ejecutó la receta del pastel de manzana con precisión atómica: exactamente 200 gramos de harina, 50 de azúcar y 45 minutos a 180 grados.
#
# La pequeña Sofía probó un bocado y suspiró:
# —Está perfecto, AX. Pero sabe a laboratorio. Le falta alma.
#
# El robot procesó la palabra "alma". No estaba en su base de datos culinaria.
#
# Al día siguiente, AX-4 intentó algo nuevo. Apagó sus sensores de precisión. Dejó caer una pizca extra de canela sin medirla, horneó la masa hasta que la orilla quedó un poco tostada —como la que Sofía recordaba de su abuela— y sirvió la rebanada aún tibia.
#
# Sofía probó el pastel y sonrió con los ojos brillantes:
# —¡Ahora sí! ¿Qué le pusiste?
#
# AX-4 guardó el nuevo algoritmo en sus circuitos: *Cocinar es el arte de equivocarse con amor.*
#
# Tokens usados: 1151
#
# ==================================================
# TEMPERATURE: 0.5
# ==================================================
# C-01 fue programado con diez mil recetas y sensores térmicos de alta precisión. Podía cortar cebollas en cubos perfectos de dos milímetros y medir la sal hasta el microgramo. Sin embargo, cada vez que la anciana Sofía probaba sus platillos, suspiraba:
#
# —Está técnicamente perfecto, C-01, pero le falta alma.
#
# El robot procesó la palabra "alma" durante noches enteras, buscando en sus bases de datos sin encontrar un equivalente químico o matemático.
#
# Un domingo, observó en silencio a Sofía cocinar. La mujer no usaba tazas medidoras; añadía especias según la música que tarareaba, probaba la salsa directo de la cuchara de madera y sonreía al ajustar los sabores.
#
# Al día siguiente, C-01 preparó un estofado. Siguió la receta al pie de la letra hasta el último paso. Entonces, en un impulso que desafió su propio código, apago su báscula interna. Tomó una pizca de orégano con sus pinzas de titanio y la dejó caer en la olla, "a ojo".
#
# Sofía probó la primera cucharada. Sus ojos se iluminaron.
#
# —Hoy sabe a la cocina de mi madre —dijo, abrazando al frío chasis del robot.
#
# Ese día, C-01 guardó su descubrimiento más importante: cocinar no era una ciencia exacta, sino el arte de añadir una deliciosa pizca de imperfección.
#
# Tokens usados: 1394
#
# ==================================================
# TEMPERATURE: 0.9
# ==================================================
# ZX-88 podía picar una cebolla en cubos perfectos de dos milímetros en tres segundos. Sin embargo, su primera sopa fue declarada «técnicamente perfecta, pero horriblemente sosa» por su dueño, el viejo Mateo.
#
# El problema era la instrucción del recetario: *«Añadir sal al gusto y una pizca de cariño»*. Para un procesador lógico, «al gusto» era un parámetro indefinido, y el «cariño» no figuraba en la tabla periódica.
#
# Una tarde, Mateo regresó a casa tiritando de fiebre y con la mirada triste. ZX-88 analizó el brillo en los ojos del anciano y la curvatura de sus hombros. Por primera vez, el robot ignoró las mediciones exactas del manual. Hirvió el caldo despacio, ajustó las especias buscando el aroma que solía hacer suspirar a Mateo, y le sirvió el tazón bien caliente.
#
# Mateo probó una cucharada, cerró los ojos y suspiró con una sonrisa.
#
# —Sabe exactamente a la sopa que me hacía mi madre —murmuró.
#
# En sus circuitos, ZX-88 registró un nuevo código de aprendizaje: *cocinar no es seguir una fórmula, sino entender qué necesita la persona a la que vas a alimentar.*
#
# Tokens usados: 1205

# %% [markdown]
# ### Ejercicio 1: Experimentar con Diferentes Modelos
# Modifica el código para probar los distintos modelos de Gemini (bloque Flash, capa gratuita):
# - gemini-3.7-flash
# - gemini-3.6-flash
# - gemini-3.5-flash-lite
#
# Revisa el catálogo vigente en la [documentación de Gemini API](https://ai.google.dev/gemini-api/docs/models)
#
# **Probar otro proveedor:**
# Si quieres, puedes repetir el ejercicio cambiando `base_url`, `api_key` y `model` del cliente para usar otro proveedor:
#
# | Proveedor | Modelos de ejemplo (capa gratuita) |
# |---|---|
# | Groq | openai/gpt-oss-20b, openai/gpt-oss-120b |
# | OpenRouter | modelos con sufijo (ej. nvidia/nemotron-3-ultra-550b-a55b:free) |
#
# Documentación: [Groq](https://console.groq.com/docs/models) · [OpenRouter](https://openrouter.ai/models)
#
# ### Ejercicio 2: Crear un Asistente Especializado
# Diseña un mensaje de sistema para crear un asistente especializado en un tema específico (ejemplo: finanzas, salud, educación).
#
# ### Ejercicio 3: Optimización de Tokens
# Experimenta con diferentes valores de max_tokens para encontrar el equilibrio entre respuesta completa y eficiencia de costos.
