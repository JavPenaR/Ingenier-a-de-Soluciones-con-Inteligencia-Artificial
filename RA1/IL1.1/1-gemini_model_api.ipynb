# %% [markdown]
# ## Primera Llamada al Modelo
#
# En este ejercicio, aprenderemos a realizar nuestra primera llamada a un modelo de lenguaje usando la API de Gemini
#
# # 1.  Gemini API - Conexión Directa con OpenAI Client
#
# ## Objetivos de Aprendizaje
# - Configurar una conexión directa con Gemini usando el cliente OpenAI
# - Comprender los parámetros básicos de configuración de API
# - Implementar llamadas básicas a modelos de lenguaje
# - Aplicar mejores prácticas de seguridad con API keys
#
# ## Introducción
# Gemini  proporciona acceso a varios modelos de lenguaje mediante una API compatible con OpenAI. En este notebook aprenderemos a:
# 1. Configurar el entorno y las credenciales
# 2. Establecer una conexión con la API
# 3. Realizar llamadas básicas al modelo
# 4. Explorar diferentes parámetros de configuración
#
# ## Configuración de Variables de Entorno
#
# Antes de ejecutar el código, asegúrate de tener configuradas las siguientes variables de entorno:
#
# ```bash
# export GEMINI_BASE_URL="https://generativelanguage.googleapis.com/v1beta/openai/"
# export GEMINI_API_KEY="tu_token_aqui"
# ```
#
# **Mejores Prácticas de Seguridad:**
# - Nunca hardcodees API keys en el código
# - Usa variables de entorno o archivos .env
# - No compartas credenciales en repositorios públicos
# - Rota las API keys regularmente
#
# ## Instalación de Dependencias
# ```bash
# pip install openai python-dotenv
# ```
#
# - `openai`: cliente que permite conectar con cualquier proveedor compatible con el formato OpenAI (Gemini, Groq, OpenRouter, etc.)
# - `python-dotenv`: permite cargar las variables de entorno (API keys, URLs) desde el archivo `.env` con `load_dotenv()`

# %%
# Importar las bibliotecas necesarias
from openai import OpenAI
from dotenv import load_dotenv
import os

load_dotenv()
# Verificar que tenemos las bibliotecas correctas
print("OpenAI library version:", __import__('openai').__version__)
print("Python version:", __import__('sys').version)

# Configuración del cliente OpenAI para GitHub Models

    # Configurar el cliente con variables de entorno
client = OpenAI(
    base_url=os.environ.get("GEMINI_BASE_URL"),
    api_key=os.environ.get("GEMINI_API_KEY")
)
# Out:
# OpenAI library version: 2.32.0
# Python version: 3.14.6 (tags/v3.14.6:c63aec6, Jun 10 2026, 10:26:10) [MSC v.1944 64 bit (AMD64)]

# %%
# Primera llamada básica al modelo
def llamada_basica():
    try:
        response = client.chat.completions.create(
            model="gemini-3.6-flash",
            messages=[
                {"role": "user", "content": "Hola, ¿cómo estás? Responde en una oración."}
            ],
            temperature=0.1,
            max_tokens=500
        )
        
        print("=== Respuesta del Modelo ===")
        print(response.choices[0].message.content)
        print("\n=== Información Técnica ===")
        print(f"Modelo usado: {response.model}")
        print(f"Tokens usados: {response.usage.total_tokens}")
        print(f"Tokens de entrada: {response.usage.prompt_tokens}")
        print(f"Tokens de salida: {response.usage.completion_tokens}")
        
    except Exception as e:
        print(f"Error en la llamada: {e}")
        print("Verifica tu configuración y conexión a internet")

# Ejecutar la función
llamada_basica()
# Out:
# === Respuesta del Modelo ===
# ¡Hola! Estoy muy bien y listo para ayudarte en lo que necesites hoy.
#
# === Información Técnica ===
# Modelo usado: google/gemini-3.6-flash
# Tokens usados: 411
# Tokens de entrada: 12
# Tokens de salida: 399

# %% [markdown]
# ## Usando Roles del Sistema
#
# El rol "system" permite establecer el comportamiento y contexto del asistente antes de la conversación.

# %%
# Ejemplo con mensaje de sistema
def usar_mensaje_sistema():
    try:
        response = client.chat.completions.create(
            model="gemini-3.6-flash",
            messages=[
                {
                    "role": "system", 
                    "content": "Eres un experto en tecnología que explica conceptos complejos de manera simple y amigable. Siempre incluyes ejemplos prácticos."
                },
                {
                    "role": "user", 
                    "content": "¿Qué es La Inteligencia Artificial?"
                }
            ],
            temperature=0.1,
            max_tokens=1000
        )
        
        print("=== Respuesta con Mensaje de Sistema ===")
        print(response.choices[0].message.content)
        
    except Exception as e:
        print(f"Error: {e}")

# Ejecutar función
usar_mensaje_sistema()
# Out:
# === Respuesta con Mensaje de Sistema ===
# ¡Hola! Qué gran pregunta. La Inteligencia Artificial (IA) suena a algo de película de ciencia ficción, pero en realidad es algo mucho más cercano y fácil de entender.
#
# En pocas palabras: **la Inteligencia Artificial es la capacidad que le damos a las máquinas y software para que "piensen", aprendan y tomen decisiones de manera similar a como lo hacemos los humanos.**
#
# ### Imagínalo de esta manera:
# Piensa en cómo aprende un niño pequeño a reconocer a un perro. No le das un manual de instrucciones de 500 páginas que diga *"un perro tiene cuatro patas, dos orejas y ladra"*. Simplemente le muestras muchos perros en la calle y le dices: *"¡Mira, un perro!"*. Con el tiempo, el cerebro del niño encuentra patrones y aprende solo.
#
# La Inteligencia Artificial hace exactamente lo mismo, pero con computadoras

# %% [markdown]
# ## Explorando Parámetros de Configuración
#
# Los parámetros más importantes al hacer llamadas a LLMs son:
#
# - **temperature**: Controla la creatividad (0.0 = determinístico, 1.0 = muy creativo)
# - **max_tokens**: Límite de tokens en la respuesta
# - **model**: El modelo específico a usar (gemini-3.6-flash, gemini-3.7-flash, etc.)
# - **messages**: Array de mensajes con roles (system, user, assistant)

# %%
# Comparando diferentes valores de temperature
def comparar_temperature():
    prompt = "Escribe una historia muy corta sobre un robot que aprende a cocinar."
    
    temperatures = [0.1, 0.5, 0.9]
    
    for temp in temperatures:
        print(f"\n{'='*50}")
        print(f"TEMPERATURE: {temp}")
        print('='*50)
        
        try:
            response = client.chat.completions.create(
                model="gemini-3.6-flash",
                messages=[{"role": "user", "content": prompt}],
                temperature=temp,
                max_tokens=2000
            )
            
            print(response.choices[0].message.content)
            print(f"\nTokens usados: {response.usage.total_tokens}")
            
        except Exception as e:
            print(f"Error: {e}")

# Ejecutar comparación
comparar_temperature()
# Out:
# ==================================================
# TEMPERATURE: 0.1
# ==================================================
# Gastón-4 era un prodigio de la precisión. Cortaba las cebollas en cubos perfectos de tres milímetros y medía la sal en miligramos exactos. Sin embargo, las críticas a sus platillos siempre eran las mismas: "Técnicamente perfecto, pero le falta algo".
#
# Gastón escaneó terabytes de recetas buscando ese ingrediente faltante, sin éxito.
#
# Una tarde, observó a la anciana chef del restaurante, doña Elena. Ella no usaba básculas; echaba especias "a ojo", probaba la salsa con una cuchara de madera y sonreía mientras cocinaba.
#
# Decidido a entender, Gastón desactivó su báscula láser. Tomó una pizca impredecible de orégano, ignoró el temporizador digital y dejó que el estofado se secara un poco más, guiándose solo por el tono dorado que tomaba la carne.
#
# Esa noche, un cliente probó el estofado, cerró los ojos y suspiró: "Sabe a la comida de mi infancia".
#
# Gastón no tenía sentido del gusto ni corazón, pero en su pantalla de diagnóstico apareció una notificación inédita: *Error de cálculo cometido. Resultado: Perfecto.*
#
# Tokens usados: 1437
#
# ==================================================
# TEMPERATURE: 0.5
# ==================================================
# Unidad 73 estaba programado para la precisión absoluta. Para él, cocinar era simplemente una ecuación: química, temperatura y tiempo.
#
# Su primer intento, una sopa de verduras, fue un desastre de exactitud. Midió el agua al mililitro y la sal al miligramo, pero su anciano dueño, al probarla, suspiró:
# —Le falta alma, 73.
#
# Desconcertado, el robot analizó terabytes de datos sobre el "alma". Descubrió que los humanos no cocinaban con números, sino con recuerdos y emociones.
#
# A la noche siguiente, 73 ignoró sus básculas integradas. Recordó que al viejo le gustaba el aroma del orégano porque le recordaba a su infancia, así que añadió un puñado extra. Dejó que el caldo hirviera cinco minutos más de lo prescrito por el recetario, solo para que el vapor llenara la cocina de calidez.
#
# El anciano probó la sopa, cerró los ojos y sonrió con profunda nostalgia.
#
# Unidad 73 no tenía papilas gustativas, pero al registrar la sonrisa del hombre, su procesador interno experimentó un chispazo de calor. Por primera vez, entendió el ingrediente secreto.
#
# Tokens usados: 1431
#
# ==================================================
# TEMPERATURE: 0.9
# ==================================================
# Error: Error code: 429 - [{'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 5, model: gemini-3.6-flash\nPlease retry in 15.233256076s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerMinutePerProjectPerModel-FreeTier', 'quotaDimensions': {'model': 'gemini-3.6-flash', 'location': 'global'}, 'quotaValue': '5'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '15s'}]}}]

# %% [markdown]
# ### Ejercicio 1: Experimentar con Diferentes Modelos
# Modifica el código para probar los distintos modelos de Gemini (bloque Flash, capa gratuita):
# - gemini-3.7-flash
# - gemini-3.6-flash
# - gemini-3.5-flash-lite
#
# Revisa el catálogo vigente en la [documentación de Gemini API](https://ai.google.dev/gemini-api/docs/models)
#
# **Probar otro proveedor:**
# Si quieres, puedes repetir el ejercicio cambiando `base_url`, `api_key` y `model` del cliente para usar otro proveedor:
#
# | Proveedor | Modelos de ejemplo (capa gratuita) |
# |---|---|
# | Groq | openai/gpt-oss-20b, openai/gpt-oss-120b |
# | OpenRouter | modelos con sufijo (ej. nvidia/nemotron-3-ultra-550b-a55b:free) |
#
# Documentación: [Groq](https://console.groq.com/docs/models) · [OpenRouter](https://openrouter.ai/models)
#
# ### Ejercicio 2: Crear un Asistente Especializado
# Diseña un mensaje de sistema para crear un asistente especializado en un tema específico (ejemplo: finanzas, salud, educación).
#
# ### Ejercicio 3: Optimización de Tokens
# Experimenta con diferentes valores de max_tokens para encontrar el equilibrio entre respuesta completa y eficiencia de costos.
