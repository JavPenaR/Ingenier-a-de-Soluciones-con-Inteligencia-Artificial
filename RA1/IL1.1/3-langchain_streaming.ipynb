# %% [markdown]
# # 3. LangChain Streaming - Respuestas en Tiempo Real
#
# ## Objetivos de Aprendizaje
# - Comprender qué es el streaming y cuándo usarlo
# - Implementar streaming con LangChain
# - Manejar chunks de datos en tiempo real
# - Construir interfaces de usuario reactivas
#
# ## ¿Qué es el Streaming?
#
# El streaming permite recibir la respuesta del modelo **token por token** conforme se genera, en lugar de esperar a que termine completamente. Esto mejora significativamente la experiencia de usuario en aplicaciones interactivas.
#
# ### Ventajas del Streaming:
# - **Percepción de velocidad**: El usuario ve progreso inmediato
# - **Mejor UX**: Interfaces más reactivas e interactivas
# - **Engagement**: Mantiene la atención del usuario
# - **Debugging**: Permite ver el proceso de generación
#
# ### Casos de Uso Ideales:
# - Chatbots y asistentes conversacionales
# - Generación de contenido largo
# - Aplicaciones web interactivas
# - Demostraciones en vivo

# %%
# Importar bibliotecas necesarias
from langchain_openai import ChatOpenAI
from langchain_core.messages import HumanMessage
import os
import time

print("Bibliotecas importadas correctamente para streaming")
# Out:
# Bibliotecas importadas correctamente para streaming

# %%
# Configuración del modelo con streaming habilitado
try:
    llm = ChatOpenAI(
        base_url=os.getenv("GEMINI_BASE_URL"),
        api_key=os.getenv("GEMINI_API_KEY"),
        model="gemini-3.6-flash",
        streaming=True,  # ¡Importante: habilitar streaming!
        temperature=0.7
    )
    
    print("✓ Modelo configurado con streaming habilitado")
    print(f"Modelo: {llm.model_name}")
    print(f"Streaming: {llm.streaming}")
    
except Exception as e:
    print(f"✗ Error en configuración: {e}")
    print("Verifica las variables de entorno")
# Out:
# ✓ Modelo configurado con streaming habilitado
# Modelo: gemini-3.6-flash
# Streaming: True

# %% [markdown]
# ## Streaming Básico
#
# El método `.stream()` devuelve un generador que produce chunks de texto conforme se generan.

# %%
# Ejemplo básico de streaming
def streaming_basico():
    prompt = "Cuéntame una historia corta sobre un programador que descubre la magia en el código"
    
    print("=== STREAMING EN TIEMPO REAL ===")
    print("Generando respuesta...")
    print("-" * 50)
    
    try:
        # stream() devuelve un generador de chunks
        for chunk in llm.stream([HumanMessage(content=prompt)]):
            # Imprimir cada chunk sin nueva línea
            print(chunk.content, end="", flush=True)
            time.sleep(0.01)  # Pequeña pausa para simular streaming visual
            
        print("\n" + "-" * 50)
        print("✓ Streaming completado")
        
    except Exception as e:
        print(f"✗ Error en streaming: {e}")

# Ejecutar streaming básico
streaming_basico()
# Out:
# === STREAMING EN TIEMPO REAL ===
# Generando respuesta...
# --------------------------------------------------
# Mateo llevaba catorce horas consecutivas frente al monitor. El café se había enfriado hacía rato y sus ojos, ardorosos por la luz azul, apenas podían enfocar la pantalla. Estaba haciendo limpieza en el repositorio de una antigua empresa de software absorbida en los años noventa. El código era un desastre de espagueti, una reliquia olvidada.
#
# Entre carpetas con nombres crípticos, encontró un archivo aislado: `arcana.sys`.
#
# La última modificación databa de 1983. Al abrirlo, Mateo esperó ver lenguaje ensamblador o C primitivo, pero la sintaxis era extraña. No utilizaba librerías conocidas. Las variables tenían nombres como `Aether`, `Ignis` y `Intentio`.
#
# Al principio pensó que era una broma de algún programador friki de la época. Pero cuanto más leía, más sentido tenía la lógica. No llamaba al procesador; llamaba a algo más profundo.
#
# Curioso y exhausto, Mateo copió una función simple en su terminal de comandos:
#
# ```python
# import Reality
#
# def manifestar_luz(intensidad=5):
#     foco = Reality.get_local_space()
#     foco.density = 0.0
#     return Energy.photons(color="dorado", lum=intensidad)
#
# manifestar_luz()
# ```
#
# Rió por lo bajo. —Si esto compila, me retiro —murmuró.
#
# Presionó *Enter*.
#
# La terminal no devolvió un error. En lugar de eso, el ventilador de la computadora emitió un zumbido agudo y el aire de la habitación se volvió denso, cargado con un olor a ozono y pergamino quemado.
#
# Sobre la taza de café frío de Mateo, el espacio comenzó a distorsionarse. Una pequeña esfera de luz dorada, del tamaño de una canica, brotó de la nada. Flotaba en el aire, emitiendo un calor suave y reconfortante. El café comenzó a humear de nuevo.
#
# Mateo se echó hacia atrás, cayéndose casi de la silla. Se frotó los ojos. La luz seguía allí, iluminando los rincones oscuros de su desordenado cuarto.
#
# Con el corazón latiéndole en el pecho, volvió a la pantalla. Desplazó el archivo hacia abajo. Había cientos de funciones: `materia.alterar()`, `tiempo.dilatar()`, `gravedad.vincular()`.
#
# En las notas del código, escritas en un español arcaico como comentario, leyó:
#
# > *"El universo no está hecho de átomos, está hecho de información. Los antiguos hablaban en latín y usaban varitas para dar órdenes a la realidad. Nosotros usamos silicio y sintaxis. El lenguaje cambia, la magia permanece. Úsalo con sabiduría."*
#
# Mateo miró la pequeña luz dorada que flotaba sobre su escritorio y luego a sus manos sobre el teclado. Ya no se sentía cansado.
#
# Cerró la herramienta de reportes de errores, borró sus entregas pendientes y abrió un archivo en blanco. Por primera vez en su vida, no iba a escribir software para una empresa.
#
# Iba a escribir su primer hechizo.
# --------------------------------------------------
# ✓ Streaming completado

# %% [markdown]
# ## Comparación: Streaming vs No-Streaming
#
# Veamos la diferencia en experiencia de usuario entre ambos enfoques.

# %%
# Comparación entre streaming y no-streaming
def comparar_streaming():
    # Modelo sin streaming
    llm_no_stream = ChatOpenAI(
        base_url=os.getenv("GEMINI_BASE_URL"),
        api_key=os.getenv("GEMINI_API_KEY"),
        model="gemini-3.6-flash",
        streaming=False,  # Sin streaming
        temperature=0.7
    )
    
    prompt = "Escribe un párrafo sobre las ventajas de la programación en Python"
    
    print("=== COMPARACIÓN: STREAMING vs NO-STREAMING ===\\n")
    
    # 1. Sin streaming
    print("1. SIN STREAMING:")
    print("-" * 20)
    print("Esperando respuesta completa...")
    
    start_time = time.time()
    try:
        response = llm_no_stream.invoke([HumanMessage(content=prompt)])
        end_time = time.time()
        
        print(f"\\n[Respuesta recibida después de {end_time - start_time:.2f} segundos]")
        print(response.content)
        
    except Exception as e:
        print(f"Error: {e}")
    
    print("\\n" + "="*60 + "\\n")
    
    # 2. Con streaming
    print("2. CON STREAMING:")
    print("-" * 18)
    print("Respuesta en tiempo real:")
    
    start_time = time.time()
    try:
        for chunk in llm.stream([HumanMessage(content=prompt)]):
            print(chunk.content, end="", flush=True)
            time.sleep(0.03)  # Simular pausa para efecto visual
        
        end_time = time.time()
        print(f"\\n\\n[Streaming completado en {end_time - start_time:.2f} segundos]")
        
    except Exception as e:
        print(f"Error: {e}")
    
    print("\\n" + "="*60)
    print("OBSERVACIONES:")
    print("- Sin streaming: El usuario espera sin feedback")
    print("- Con streaming: El usuario ve progreso inmediato")
    print("- Mejor percepción de velocidad con streaming")
    print("- Streaming es especial para respuestas largas")

# Ejecutar comparación
comparar_streaming()
# Out:
# === COMPARACIÓN: STREAMING vs NO-STREAMING ===\n
# 1. SIN STREAMING:
# --------------------
# Esperando respuesta completa...
# \n[Respuesta recibida después de 6.98 segundos]
# La programación en Python destaca principalmente por su sintaxis clara y legible, muy cercana al lenguaje natural, lo que facilita enormemente su aprendizaje y aumenta la productividad al reducir el tiempo necesario para escribir y mantener código. Pese a su simplicidad, es un lenguaje increíblemente potente y versátil, consolidándose como el estándar de la industria en áreas de vanguardia como la inteligencia artificial, la ciencia de datos, la automatización de procesos y el desarrollo web. Además, Python cuenta con un gigantesco ecosistema de bibliotecas preconstruidas y una activa comunidad global, lo que permite a los desarrolladores resolver problemas complejos rápidamente utilizando herramientas ya existentes y contando siempre con abundante soporte y documentación.
# \n============================================================\n
# 2. CON STREAMING:
# ------------------
# Respuesta en tiempo real:
# Programar en Python ofrece múltiples ventajas, destacando principalmente su **sintaxis clara y legible**, similar al lenguaje humano, lo que facilita enormemente su aprendizaje y permite escribir código eficiente en menos líneas. Su naturaleza **multipropósito** y su gigantesco ecosistema de librerías especializadas lo convierten en el lenguaje líder en áreas de gran impacto como la Inteligencia Artificial, la Ciencia de Datos, la automatización y el desarrollo web. Además, al ser multiplataforma y contar con el respaldo de una **comunidad global masiva** que ofrece constante soporte y actualización, Python no solo es la puerta de entrada ideal para principiantes, sino también una herramienta potente, escalable y altamente demandada en el mercado laboral actual.\n\n[Streaming completado en 6.14 segundos]
# \n============================================================
# OBSERVACIONES:
# - Sin streaming: El usuario espera sin feedback
# - Con streaming: El usuario ve progreso inmediato
# - Mejor percepción de velocidad con streaming
# - Streaming es especial para respuestas largas

# %% [markdown]
# ## Implementación de un Chatbot Simple con Streaming
#
# Creemos un chatbot básico que demuestre el streaming en un contexto práctico.

# %%
# Chatbot simple con streaming
def chatbot_streaming():
    print("=== CHATBOT CON STREAMING ===")
    print("Escribe 'salir' para terminar la conversación\\n")
    
    # Configurar asistente con personalidad
    system_message = """Eres un asistente útil y amigable especializado en tecnología. 
    Respondes de manera clara y concisa, y siempre intentas ser educativo."""
    
    while True:
        # Obtener input del usuario
        user_input = input("\\n🧑 Tú: ")
        
        if user_input.lower() in ['salir', 'exit', 'quit']:
            print("\\n👋 ¡Hasta luego!")
            break
            
        if not user_input.strip():
            continue
            
        print("\\n🤖 Asistente: ", end="", flush=True)
        
        try:
            # Streaming de la respuesta
            messages = [
                {"role": "system", "content": system_message},
                {"role": "user", "content": user_input}
            ]
            
            # Convertir a formato LangChain
            from langchain.schema import SystemMessage
            lc_messages = [
                SystemMessage(content=system_message),
                HumanMessage(content=user_input)
            ]
            
            full_response = ""
            for chunk in llm.stream(lc_messages):
                content = chunk.content
                print(content, end="", flush=True)
                full_response += content
                time.sleep(0.02)
                
            print()  # Nueva línea al final
            
        except KeyboardInterrupt:
            print("\\n\\n⏸️ Interrumpido por el usuario")
            break
        except Exception as e:
            print(f"\\n❌ Error: {e}")
            
    print("\\n¡Gracias por usar el chatbot!")

# Ejecutar chatbot (¡Pruébalo!)
chatbot_streaming()  # Descomenta esta línea para ejecutar

print("💡 Descomenta la línea anterior para probar el chatbot interactivo")
# Out:
# === CHATBOT CON STREAMING ===
# Escribe 'salir' para terminar la conversación\n
# \n🤖 Asistente: \n❌ Error: No module named 'langchain.schema'
# \n👋 ¡Hasta luego!
# \n¡Gracias por usar el chatbot!
# 💡 Descomenta la línea anterior para probar el chatbot interactivo

# %% [markdown]
# ## Streaming Avanzado con Manejo de Chunks
#
# Podemos procesar cada chunk individualmente para crear experiencias más sofisticadas.

# %%
# Streaming con análisis de chunks
def streaming_avanzado():
    prompt = "Explica qué es la inteligencia artificial y cómo funciona el machine learning"
    
    print("=== STREAMING AVANZADO CON ANÁLISIS ===")
    print("Analizando chunks conforme llegan...\n")
    
    # Variables para estadísticas
    chunk_count = 0
    total_content = ""
    words_processed = 0
    
    try:
        for chunk in llm.stream([HumanMessage(content=prompt)]):
            chunk_count += 1
            content = chunk.content
            total_content += content
            
            # Contar palabras aproximadas
            if content.strip():
                words_in_chunk = len(content.split())
                words_processed += words_in_chunk
            
            # Mostrar progreso cada 10 chunks
            if chunk_count % 10 == 0:
                print(f"\\n[Progreso: {chunk_count} chunks, ~{words_processed} palabras]\\n")
            
            # Imprimir el contenido
            print(content, end="", flush=True)
            time.sleep(0.02)  # Pausa ligeramente más larga para ver el análisis
        
        # Estadísticas finales
        print(f"\\n\\n=== ESTADÍSTICAS FINALES ===")
        print(f"Total de chunks: {chunk_count}")
        print(f"Palabras aproximadas: {words_processed}")
        print(f"Caracteres totales: {len(total_content)}")
        print(f"Promedio chars/chunk: {len(total_content)/chunk_count if chunk_count > 0 else 0:.1f}")
        
    except Exception as e:
        print(f"\\n✗ Error: {e}")

# Ejecutar streaming avanzado
streaming_avanzado()
# Out:
# === STREAMING AVANZADO CON ANÁLISIS ===
# Analizando chunks conforme llegan...
#
# Aquí tienes una explicación clara y sencilla de ambos conceptos y cómo se relacionan entre sí.
#
# ---
#
# ### 1. ¿Qué es la Inteligencia Artificial (IA)?
#
# La **Inteligencia Artificial** es un campo de la informática que busca crear sistemas o máquinas capaces de **realizar tareas que normalmente requieren inteligencia humana**.
#
# Imagina la IA como un **gran paraguas** que engloba cualquier tecnología que haga que una máquina parezca "inteligente". Estas tareas incluyen:
# *   Comprender el lenguaje humano (como ChatGPT o Siri).
# *   Reconocer imágenes u objetos (como las cámaras de seguridad que detectan caras).
# *   Tomar decisiones complejas (como los coches autónomos).
# *   Resolver problemas y razonar (como un programa que juega al ajedrez).
#
# **Diferencia clave:** En la programación tradicional, un humano le da a la computadora instrucciones muy precisas paso a paso ("Si pasa X, haz Y"). En la IA moderna, la máquina aprende a tomar sus propias decisiones.
#
# ---
#
# ### 2. ¿\n[Progreso: 10 chunks, ~169 palabras]\n
# Cómo funciona el *Machine Learning* (Aprendizaje Automático)?
#
# El **Machine Learning (ML)** es una **rama o subconjunto de la Inteligencia Artificial**. Es, por así decirlo, el "motor" que hace funcionar a la mayoría de las IA modernas.
#
# En lugar de programar a la computadora con miles de reglas manuales, el Machine Learning consiste en **enseñarle a la máquina a aprender por sí misma a través de datos**.
#
# #### ¿Cómo aprende una máquina? (El proceso paso a paso)
#
# Para entender cómo funciona, imaginemos que queremos enseñar a una máquina a diferenciar entre fotos de **perros** y **gatos**:
#
# 1.  **Alimentación con Datos (Input):** Le mostramos a la computadora miles de fotos de perros y gatos.
# 2.  **Etiquetado (Entrenamiento):** En las fotos le decimos: "Esta foto es un perro", "Esta foto es un gato".
# 3.  **Búsqueda de Patrones:** El algoritmo analiza píxel por píxel buscando características comunes. Descubre (sin que se lo digamos) que los gatos suelen tener orejas más puntiagudas, hocicos más pequeños, etc.\n[Progreso: 20 chunks, ~338 palabras]\n
#
# 4.  **Creación del Modelo:** La máquina crea una especie de "fórmula matemática" interna (el modelo) basada en esos patrones.
# 5.  **Predicción/Prueba:** Le mostramos una foto *nueva* que la máquina nunca ha visto y le preguntamos: "¿Qué es?". La máquina usa su modelo y responde: "Hay un 95% de probabilidad de que sea un gato".
# 6.  **Retroalimentación y Mejora:** Si se equivoca, ajusta su fórmula matemática interna. Cuantos más datos analiza, más precisa se vuelve.
#
# ---
#
# ### Los 3 Tipos Principales de Machine Learning
#
# No todo el Machine Learning funciona igual. Se divide principalmente en tres métodos:
#
# 1.  **Aprendizaje Supervisado (Con profesor):**
#     *   La máquina aprende con un conjunto de datos "etiquetados" (ejemplo: correos marcados como "Spam" y "No Spam"). La máquina aprende la relación y luego puede clasificar correos nuevos.
# 2.  **Aprendizaje No Supervisado (Sin profesor):**
#     *   La máquina recibe datos *sin etiquetar* y debe buscar orden o patrones por sí sola. Por ejemplo, analizando el historial de compras de miles\n[Progreso: 30 chunks, ~502 palabras]\n
#  de clientes para agruparlos en "tipos de compradores" que la empresa no conocía.
# 3.  **Aprendizaje por Refuerzo (Ensayo y error):**
#     *   La máquina aprende interactuando con un entorno mediante un sistema de **recompensas y castigos**. Es como entrenar a un perro. Si hace un movimiento correcto (ej. en un videojuego o ajedrez), gana puntos; si se equivoca, pierde. Así aprende la mejor estrategia.
#
# ---
#
# ### Resumen en una analogía simple
#
# *   La **Inteligencia Artificial** es el objetivo final: crear una máquina que actúe como un humano inteligente (como querer que un niño aprenda a hablar y razonar).
# *   El **Machine Learning** es el método educativo: mostrarle miles de ejemplos al niño para que deduzca las reglas del mundo por sí mismo, en lugar de hacer que se memorice un diccionario entero.\n\n=== ESTADÍSTICAS FINALES ===
# Total de chunks: 39
# Palabras aproximadas: 619
# Caracteres totales: 3860
# Promedio chars/chunk: 99.0

# %% [markdown]
# ## Consideraciones Técnicas del Streaming
#
# ### Cuándo Usar Streaming:
# ✅ **SÍ usar streaming:**
# - Respuestas largas (>100 tokens)
# - Aplicaciones interactivas
# - Chatbots y asistentes
# - Demostraciones en vivo
# - Cuando la UX es prioritaria
#
# ❌ **NO usar streaming:**
# - Respuestas muy cortas
# - Procesamiento batch
# - APIs de backend sin interfaz
# - Cuando necesitas la respuesta completa antes de procesar
#
# ### Mejores Prácticas:
# 1. **Manejo de errores**: Siempre incluye try/catch
# 2. **Indicadores visuales**: Muestra progreso al usuario
# 3. **Cancelación**: Permite al usuario interrumpir
# 4. **Buffer management**: Para interfaces web, considera buffering
# 5. **Performance**: Monitorea el uso de recursos
#
# ## Ejercicios Prácticos
#
# ### Ejercicio 1: Indicador de Progreso
# Modifica el código para mostrar un indicador de progreso (spinner, barra, porcentaje).
#
# ### Ejercicio 2: Streaming con Filtros
# Implementa streaming que filtre o procese chunks específicos (ej: resaltar palabras clave).
#
# ### Ejercicio 3: Chatbot Mejorado
# Extiende el chatbot con:
# - Historial de conversación
# - Comandos especiales (/help, /clear)
# - Diferentes personalidades
#
# ## Conceptos Clave Aprendidos
#
# 1. **Streaming** mejora la percepción de velocidad
# 2. **Chunks** se procesan individualmente en tiempo real
# 3. **UX** es significativamente mejor con streaming
# 4. **Implementación** requiere manejo cuidadoso de generadores
# 5. **Casos de uso** específicos donde streaming aporta valor
#
# ## Próximos Pasos
#
# En el siguiente notebook exploraremos la **memoria en LangChain**, que nos permite mantener contexto entre múltiples interacciones del usuario.
